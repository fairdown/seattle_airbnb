# %%
import pandas as pd

# %%
df = pd.read_csv('./listings.csv')

# %%
df.head()
# Out:
#         id                           listing_url       scrape_id last_scraped  \
# 0   241032   https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 1   953595   https://www.airbnb.com/rooms/953595  20160104002432   2016-01-04
# 2  3308979  https://www.airbnb.com/rooms/3308979  20160104002432   2016-01-04
# 3  7421966  https://www.airbnb.com/rooms/7421966  20160104002432   2016-01-04
# 4   278830   https://www.airbnb.com/rooms/278830  20160104002432   2016-01-04
#
#                                   name  \
# 0         Stylish Queen Anne Apartment
# 1   Bright & Airy Queen Anne Apartment
# 2  New Modern House-Amazing water view
# 3                   Queen Anne Chateau
# 4       Charming craftsman 3 bdm house
#
#                                              summary  \
# 0                                                NaN
# 1  Chemically sensitive? We've removed the irrita...
# 2  New modern house built in 2013.  Spectacular s...
# ...

# %%
df.shape
# Out:
# (3818, 92)

# %% [markdown]
# # Check all the data columns.
# Trying to get some important columns from this data

# %%
df.columns.values.tolist()
# Out:
# ['id',
#  'listing_url',
#  'scrape_id',
#  'last_scraped',
#  'name',
#  'summary',
#  'space',
#  'description',
#  'experiences_offered',
#  'neighborhood_overview',
#  'notes',
#  'transit',
#  'thumbnail_url',
#  'medium_url',
#  'picture_url',
#  'xl_picture_url',
#  'host_id',
#  'host_url',
#  'host_name',
#  'host_since',
#  'host_location',
#  'host_about',
#  'host_response_time',
#  'host_response_rate',
#  'host_acceptance_rate',
#  'host_is_superhost',
#  'host_thumbnail_url',
#  'host_picture_url',
#  'host_neighbourhood',
#  'host_listings_count',
#  'host_total_listings_count',
#  'host_verifications',
#  'host_has_profile_pic',
#  'host_identity_verified',
#  'street',
#  'neighbourhood',
#  'neighbourhood_cleansed',
#  'neighbourhood_group_cleansed',
#  'city',
#  'state',
#  'zipcode',
#  'market',
#  'smart_location',
#  'country_code',
#  'country',
#  'latitude',
#  'longitude',
#  'is_location_exact',
#  'property_type',
#  'room_type',
#  'accommodates',
# ...

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3818 entries, 0 to 3817
# Data columns (total 92 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                3818 non-null   int64
#  1   listing_url                       3818 non-null   object
#  2   scrape_id                         3818 non-null   int64
#  3   last_scraped                      3818 non-null   object
#  4   name                              3818 non-null   object
#  5   summary                           3641 non-null   object
#  6   space                             3249 non-null   object
#  7   description                       3818 non-null   object
#  8   experiences_offered               3818 non-null   object
#  9   neighborhood_overview             2786 non-null   object
#  10  notes                             2212 non-null   object
# ...

# %% [markdown]
# # Check the reviews
# First, I'm checking the number of reviews by days available.

# %%
df[['number_of_reviews', 'availability_30', 'availability_60', 'availability_90', 'availability_365']]
# Out:
#       number_of_reviews  availability_30  availability_60  availability_90  \
# 0                   207               14               41               71
# 1                    43               13               13               16
# 2                    20                1                6               17
# 3                     0                0                0                0
# 4                    38               30               60               90
# ...                 ...              ...              ...              ...
# 3813                  1               18               32               32
# 3814                  2                6               26               44
# 3815                  0               29               59               88
# 3816                  0               30               60               90
# 3817                  0                7                7                7
#
#       availability_365
# 0                  346
# ...

# %% [markdown]
# Verifying the score of each topic and removing the null columns

# %%
reviews_scores = df[['id','review_scores_rating',
 'review_scores_accuracy',
 'review_scores_cleanliness',
 'review_scores_checkin',
 'review_scores_communication',
 'review_scores_location',
 'review_scores_value','number_of_reviews']]

# %%
reviews_scores = reviews_scores[reviews_scores['review_scores_rating'].notnull()]

# %% [markdown]
# Get the mean and the median score rating

# %%
reviews_scores['review_scores_rating'].mean()
# Out:
# 94.53926206244087

# %%
reviews_scores['review_scores_rating'].median()
# Out:
# 96.0

# %% [markdown]
# # Checking the scores.

# %%
reviews_scores['review_scores_rating'].describe()
# Out:
# count    3171.000000
# mean       94.539262
# std         6.606083
# min        20.000000
# 25%        93.000000
# 50%        96.000000
# 75%        99.000000
# max       100.000000
# Name: review_scores_rating, dtype: float64

# %% [markdown]
# ## Scores Rating below or equal 50

# %%
reviews_scores[reviews_scores['review_scores_rating'] <= 50].sort_values(by=['review_scores_rating'], ascending=False)
# Out:
#            id  review_scores_rating  review_scores_accuracy  \
# 1162  9151865                  40.0                     4.0
# 1666  9151374                  40.0                     4.0
# 2320  8474294                  40.0                    10.0
# 3148  5639238                  40.0                     9.0
# 1222  9183838                  20.0                     2.0
#
#       review_scores_cleanliness  review_scores_checkin  \
# 1162                       10.0                   10.0
# 1666                        6.0                    8.0
# 2320                       10.0                    2.0
# 3148                        3.0                    9.0
# 1222                        4.0                    2.0
#
#       review_scores_communication  review_scores_location  \
# 1162                         10.0                    10.0
# 1666                          2.0                     8.0
# 2320                          2.0                    10.0
# ...

# %% [markdown]
# ## Reviews Above 50

# %%
reviews_scores[reviews_scores['review_scores_rating'] > 50].sort_values(by=['review_scores_rating'], ascending=False)
# Out:
#            id  review_scores_rating  review_scores_accuracy  \
# 3814  8902327                 100.0                    10.0
# 1144  5330475                 100.0                     9.0
# 639   9210978                 100.0                    10.0
# 1160  7438635                 100.0                    10.0
# 1159  7840228                 100.0                    10.0
# ...       ...                   ...                     ...
# 806   9303530                  60.0                     8.0
# 2495  7245586                  60.0                     6.0
# 1972  9075558                  57.0                     6.0
# 1219  6370313                  55.0                     7.0
# 2474  4892529                  53.0                     6.0
#
#       review_scores_cleanliness  review_scores_checkin  \
# 3814                       10.0                   10.0
# 1144                        9.0                   10.0
# 639                        10.0                   10.0
# ...

# %%
reviews_scores.sort_values(by=['number_of_reviews'], ascending=False).head(20)
# Out:
#            id  review_scores_rating  review_scores_accuracy  \
# 1447   208356                  95.0                    10.0
# 1441   365550                  94.0                     9.0
# 3083    25002                  98.0                    10.0
# 3600    47196                  93.0                    10.0
# 2568    63308                  98.0                    10.0
# 1499    92835                  94.0                    10.0
# 2166     5682                  96.0                    10.0
# 2690   279063                  91.0                     9.0
# 2456    53867                  96.0                    10.0
# 2668   841049                  95.0                    10.0
# 2610   258571                  89.0                     9.0
# 3291   158345                  97.0                    10.0
# 821    794633                  98.0                    10.0
# 1462   397117                  95.0                    10.0
# 2710   835149                  96.0                    10.0
# ...

# %%
reviews_scores[reviews_scores['number_of_reviews']>=100].sort_values(by=['number_of_reviews'], ascending=False)
# Out:
#            id  review_scores_rating  review_scores_accuracy  \
# 1447   208356                  95.0                    10.0
# 1441   365550                  94.0                     9.0
# 3083    25002                  98.0                    10.0
# 3600    47196                  93.0                    10.0
# 2568    63308                  98.0                    10.0
# ...       ...                   ...                     ...
# 2497  3852117                  94.0                    10.0
# 2107  5056580                 100.0                    10.0
# 407   2026794                  91.0                     9.0
# 1703  1080097                  93.0                     9.0
# 3158  1622794                  98.0                    10.0
#
#       review_scores_cleanliness  review_scores_checkin  \
# 1447                       10.0                   10.0
# 1441                       10.0                   10.0
# 3083                       10.0                   10.0
# ...

# %%
## Conclusion

Guests usually enjoy their stay
